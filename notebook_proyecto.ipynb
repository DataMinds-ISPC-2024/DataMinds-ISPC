# %% [markdown]
# ![ISPC_portada.png](attachment:fc7858ac-7dfa-438e-b21d-ea0cdb138ffb.png)

# %% [markdown]
# # **Análisis de Datos de RRHH de la empresa BioTech Innovations S.A.**

# %% [markdown]
# ##   **DataMinds-ISPC** - Grupo – Integrantes:
# * 1. Angiolini Sofía Carla
# * 2. Ayán María Trinidad
# * 3. Donati Camila
# * 4. Giordano Ariel Eduardo
# * 5. Herrera Edgar Fabián
# * 6. López María Gabriela
# * 7. Quiroga Fernanda
# * 8. Valvassori Etelvina Graciela

# %% [markdown]
# ## Descripción del Proyecto:

# %% [markdown]
# **“BioTech Innovations S.A.”**, es una empresa líder en el campo de la biotecnología y las ciencias de la vida. Fundada hace 15 años, la empresa se dedica a la investigación, desarrollo y comercialización de soluciones innovadoras para la industria médica y científica. Con un enfoque en la mejora de la calidad de vida a través de la innovación tecnológica, BioTech Innovations combina la investigación de vanguardia con la aplicación práctica para ofrecer productos y servicios de alta calidad.
# BioTech Innovations S.A. se esfuerza por mantener un ambiente de trabajo dinámico y satisfactorio, apoyando a sus empleados en su desarrollo profesional y personal. Con un compromiso constante hacia la excelencia y la innovación, la empresa sigue creciendo y marcando la diferencia en el campo de la biotecnología.
#
# La empresa considera a los empleados como el recurso más valioso. **A continuación, se presenta un estudio realizado por el área de recursos humanos de la empresa, que desea estudiar los perfiles representativos de los empleados, destacando su diversidad en términos de edad, roles laborales y niveles de satisfacción.**

# %%
import pandas as pd

# %%
df = pd.read_csv('dataminds_dataset.csv')

# %%
df
# Out:
#      Unnamed: 0 Unnamed: 1            Unnamed: 2                  Unnamed: 3  \
# 0          Edad   Renunció     Viaja por trabajo                Departamento
# 1           4 1         Sí        Rara Vez Viaja                      Ventas
# 2            49         No  Viaja Frecuentemente  Investigación y Desarrollo
# 3            37         Sí        Rara Vez Viaja  Investigación y Desarrollo
# 4            33         No  Viaja Frecuentemente  Investigación y Desarrollo
# ...         ...        ...                   ...                         ...
# 1468         27         No        Rara Vez Viaja  Investigación y Desarrollo
# 1469         49         No  Viaja Frecuentemente                      Ventas
# 1470         34         No        Rara Vez Viaja  Investigación y Desarrollo
# 1471        NaN        NaN                   NaN                         NaN
# 1472        NaN        NaN                   NaN                         NaN
#
#                     Unnamed: 4          Unnamed: 5           Unnamed: 6  \
# 0     Distancia a su casa (km)  Nivel de educacion     Campo de estudio
# 1                            1                   2  Ciencias de la Vida
# 2                            8                   1  Ciencias de la Vida
# 3                            2                   2                 Otro
# 4                            3                   4  Ciencias de la Vida
# ...                        ...                 ...                  ...
# 1468                         4                   3  Ciencias de la Vida
# 1469                         2                   3             Medicina
# 1470                         8                   3             Medicina
# 1471                       NaN                 NaN                  NaN
# 1472                       NaN                 NaN                  NaN
#
#                Unnamed: 7       Unnamed: 8 Unnamed: 9  ...   Unnamed: 12  \
# 0     Numero de empleado   Entorno laboral     Género  ...  Estado civil
# 1                       1                2   Femenino  ...       Soltero
# 2                       2                3  Masculino  ...        Casado
# 3                       4                4  Masculino  ...       Soltero
# 4                       5                4   Femenino  ...         Casdo
# ...                   ...              ...        ...  ...           ...
# 1468                 2064                2  Masculino  ...        Casado
# 1469                 2065                4  Masculino  ...        Casado
# 1470                 2068                2  Masculino  ...         viudo
# 1471                  NaN              NaN        NaN  ...           NaN
# 1472                  NaN              NaN        NaN  ...           NaN
#
#                          Unnamed: 13  \
# 0     Porcentaje Aumento Del Salario
# 1                                 11
# 2                                 23
# 3                                 15
# 4                                 11
# ...                              ...
# 1468                              20
# 1469                              14
# 1470                              12
# 1471                             NaN
# 1472                             NaN
#
#      Como describiria las relaciones en su lugar de trabajo  \
# 0                            Satisfaccion de relaciones
# 1                                                     1
# 2                                                     4
# 3                                                     2
# 4                                                     3
# ...                                                 ...
# 1468                                                  2
# 1469                                                  4
# 1470                                                  1
# 1471                                                NaN
# 1472                                                NaN
#
#                        Unnamed: 15 Total de años trabajados  \
# 0     Cantidad de horas trabajadas       Antiguedad laboral
# 1                               80                        8
# 2                               80                       10
# 3                               80                        7
# 4                               80                        8
# ...                            ...                      ...
# 1468                            80                        6
# 1469                            80                       17
# 1470                            80                        6
# 1471                           NaN                      NaN
# 1472                           NaN                      NaN
#
#                    Unnamed: 17                      Unnamed: 18  \
# 0     Antiguedad en la empresa  Capacitaciones del año anterior
# 1                            6                                0
# 2                          100                                3
# 3                            0                                3
# 4                            8                                3
# ...                        ...                              ...
# 1468                         6                                0
# 1469                         9                                3
# 1470                         4                                3
# 1471                       NaN                              NaN
# 1472                       NaN                              NaN
#
#                         Unnamed: 19                   Unnamed: 20  \
# 0     Antiguedad en el mismo puesto  Años desde el ultimo ascenso
# 1                                 4                             0
# 2                                 7                             1
# 3                                 0                             0
# 4                                 7                             3
# ...                             ...                           ...
# 1468                              2                             0
# 1469                              6                             0
# 1470                              3                             1
# 1471                            NaN                           NaN
# 1472                            NaN                           NaN
#
#                     Unnamed: 21
# 0     Años con el mismo gerente
# 1                            50
# 2                             7
# 3                             0
# 4                             0
# ...                         ...
# 1468                          3
# 1469                          8
# 1470                          2
# 1471                        NaN
# 1472                        NaN
#
# [1473 rows x 22 columns]

# %%
print(df.head(11))
# Out:
#    Unnamed: 0 Unnamed: 1            Unnamed: 2                  Unnamed: 3  \
# 0        Edad   Renunció     Viaja por trabajo                Departamento
# 1         4 1         Sí        Rara Vez Viaja                      Ventas
# 2          49         No  Viaja Frecuentemente  Investigación y Desarrollo
# 3          37         Sí        Rara Vez Viaja  Investigación y Desarrollo
# 4          33         No  Viaja Frecuentemente  Investigación y Desarrollo
# 5          27         No        Rara Vez Viaja  Investigación y Desarrollo
# 6          32         No  Viaja Frecuentemente  Investigación y Desarrollo
# 7          59         No        Rara Vez Viaja  Investigación y Desarrollo
# 8          30         No        Rara Vez Viaja  Investigación y Desarrollo
# 9          38         No  Viaja Frecuentemente  Investigación y Desarrollo
# 10         36         No                 Viaja  Investigación y Desarrollo
#
#                   Unnamed: 4          Unnamed: 5           Unnamed: 6  \
# 0   Distancia a su casa (km)  Nivel de educacion     Campo de estudio
# 1                          1                   2  Ciencias de la Vida
# 2                          8                   1  Ciencias de la Vida
# 3                          2                   2                 Otro
# 4                          3                   4  Ciencias de la Vida
# 5                          2                   1             Medicina
# 6                          2                   2  Ciencias de la Vida
# 7                          3                   3             Medicina
# 8                         24                   1  Ciencias de la Vida
# 9                         23                   3  Ciencias de la Vida
# 10                        27                   3             Medicina
#
#              Unnamed: 7       Unnamed: 8 Unnamed: 9  ...   Unnamed: 12  \
# 0   Numero de empleado   Entorno laboral     Género  ...  Estado civil
# 1                     1                2   Femenino  ...       Soltero
# 2                     2                3  Masculino  ...        Casado
# 3                     4                4  Masculino  ...       Soltero
# 4                     5                4   Femenino  ...         Casdo
# 5                     7                1  Masculino  ...        Casado
# 6                     8                4  Masculino  ...       Soltero
# 7                    10                3   Femenino  ...        Casado
# 8                    11                4  Masculino  ...    Divorciado
# 9                    12                4  Masculino  ...       Soltero
# 10                   13                3  Masculino  ...        Casado
#
#                        Unnamed: 13  \
# 0   Porcentaje Aumento Del Salario
# 1                               11
# 2                               23
# 3                               15
# 4                               11
# 5                               12
# 6                               13
# 7                               20
# 8                               22
# 9                               21
# 10                              13
#
#    Como describiria las relaciones en su lugar de trabajo  \
# 0                          Satisfaccion de relaciones
# 1                                                   1
# 2                                                   4
# 3                                                   2
# 4                                                   3
# 5                                                   4
# 6                                                   3
# 7                                                   1
# 8                                                   2
# 9                                                   2
# 10                                                  2
#
#                      Unnamed: 15 Total de años trabajados  \
# 0   Cantidad de horas trabajadas       Antiguedad laboral
# 1                             80                        8
# 2                             80                       10
# 3                             80                        7
# 4                             80                        8
# 5                             80                        6
# 6                             80                        8
# 7                             80                       12
# 8                             80                        1
# 9                             80                       10
# 10                            80                       17
#
#                  Unnamed: 17                      Unnamed: 18  \
# 0   Antiguedad en la empresa  Capacitaciones del año anterior
# 1                          6                                0
# 2                        100                                3
# 3                          0                                3
# 4                          8                                3
# 5                          2                                3
# 6                          7                                2
# 7                          1                                3
# 8                          1                                2
# 9                          9                                2
# 10                         7                                3
#
#                       Unnamed: 19                   Unnamed: 20  \
# 0   Antiguedad en el mismo puesto  Años desde el ultimo ascenso
# 1                               4                             0
# 2                               7                             1
# 3                               0                             0
# 4                               7                             3
# 5                               2                             2
# 6                               7                             3
# 7                               0                             0
# 8                               0                             0
# 9                               7                             1
# 10                              7                             7
#
#                   Unnamed: 21
# 0   Años con el mismo gerente
# 1                          50
# 2                           7
# 3                           0
# 4                           0
# 5                           2
# 6                           6
# 7                           0
# 8                           0
# 9                           8
# 10                          7
#
# [11 rows x 22 columns]

# %% [markdown]
# ## **Descripción básica del dataset:**

# %%
print(f"Total de registros:{df.shape[0]}")
# Out:
# Total de registros:1473

# %%
print(f"Total de columnas:{df.shape[1]}")
# Out:
# Total de columnas:22

# %%
print("\nTipos de datos por columna:")
print(df.dtypes)
# Out:
# Tipos de datos por columna:
# Unnamed: 0                                                object
# Unnamed: 1                                                object
# Unnamed: 2                                                object
# Unnamed: 3                                                object
# Unnamed: 4                                                object
# Unnamed: 5                                                object
# Unnamed: 6                                                object
# Unnamed: 7                                                object
# Unnamed: 8                                                object
# Unnamed: 9                                                object
# Unnamed: 10                                               object
# Satisfaccion con su trabajo                               object
# Unnamed: 12                                               object
# Unnamed: 13                                               object
# Como describiria las relaciones en su lugar de trabajo    object
# Unnamed: 15                                               object
# Total de años trabajados                                  object
# Unnamed: 17                                               object
# Unnamed: 18                                               object
# Unnamed: 19                                               object
# Unnamed: 20                                               object
# Unnamed: 21                                               object
# dtype: object

# %% [markdown]
# ### **Estadísticas descriptivas**

# %%
print("\nEstadisticas descriptivas:")
print(df.describe(include='all'))
# Out:
# Estadisticas descriptivas:
#        Unnamed: 0 Unnamed: 1      Unnamed: 2                  Unnamed: 3  \
# count        1471       1471            1471                        1471
# unique         48          3               5                           5
# top            35         No  Rara Vez Viaja  Investigación y Desarrollo
# freq           78       1233            1042                         960
#
#        Unnamed: 4 Unnamed: 5           Unnamed: 6           Unnamed: 7  \
# count        1471       1471                 1471                 1471
# unique         30          6                    8                 1471
# top             2          3  Ciencias de la Vida  Numero de empleado
# freq          211        572                  606                    1
#
#        Unnamed: 8 Unnamed: 9  ... Unnamed: 12 Unnamed: 13  \
# count        1471       1471  ...        1471        1471
# unique          5          5  ...           7          16
# top             3  Masculino  ...      Casado          11
# freq          453        882  ...         669         210
#
#        Como describiria las relaciones en su lugar de trabajo Unnamed: 15  \
# count                                                1471            1471
# unique                                                  5               4
# top                                                     3              80
# freq                                                  459            1468
#
#        Total de años trabajados Unnamed: 17 Unnamed: 18 Unnamed: 19  \
# count                      1471        1471        1471        1471
# unique                       41          39           8          20
# top                          10           5           2           2
# freq                        202         196         547         372
#
#        Unnamed: 20 Unnamed: 21
# count         1471        1471
# unique          17          20
# top              0           2
# freq           581         344
#
# [4 rows x 22 columns]
